# %%
import os

# %%
os.getcwd()
# Out:
# 'd:\\Win_Pred_Analytics_Revised'

# %%
from pathlib import Path

# %%
workdir=str(Path("d:\\Win_Pred_Analytics_Revised"))

# %%
print(f"Current directory:{os.getcwd()}")
os.chdir(workdir)
print(f"Current directory:{os.getcwd()}")
# Out:
# Current directory:d:\Win_Pred_Analytics_Revised
# Current directory:d:\Win_Pred_Analytics_Revised

# %%
class Config:

    def __init__(self):
        self.work_dir=workdir
        self.data_dir=os.path.join("data")
        self.csv_file_name="data.csv"
        self.csv_file_path=os.path.join(self.data_dir,self.csv_file_name)
        self.pipeline_name="win_aiops_pipeline"
        self.pipeline_root=os.path.join(os.getcwd(),"win_aiops_pipeline_artifact")
        self.meta_data_path=os.path.join(os.getcwd(),"win_aiops_pipeline_metadata",self.pipeline_name,"metadata.db")

# %%
config = Config()

# %%
config.meta_data_path
# Out:
# 'd:\\Win_Pred_Analytics_Revised\\win_aiops_pipeline_metadata\\win_aiops_pipeline\\metadata.db'

# %% [markdown]
# ### How to run pipeline build using TFX
# - Interactive Context
# - LocalDagRunner
# - BeamDagRunner
# - Airflow
# - Kubeflow

# %%
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext

# %%
from tfx.orchestration.metadata import sqlite_metadata_connection_config

# %%
config.pipeline_root
# Out:
# 'd:\\Win_Pred_Analytics_Revised\\win_aiops_pipeline_artifact'

# %%
interactive_context=InteractiveContext(
    pipeline_name=config.pipeline_name,
    pipeline_root=config.pipeline_root,
    metadata_connection_config=sqlite_metadata_connection_config(config.meta_data_path)

)

# %%
from tfx.components import CsvExampleGen

# %%
csv_example_gen=CsvExampleGen(input_base=config.data_dir)

# %%
interactive_context.run(csv_example_gen)
# Out:
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 7
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 3
#         type_id: 14
#         uri: "d:\\Win_Pred_Analytics_Revised\\win_aiops_pipeline_artifact\\CsvExampleGen\\examples\\3"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "file_format"
#           value {
#             string_value: "tfrecords_gzip"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:single_split,num_files:1,total_bytes:917077,xor_checksum:1655399370,sum_checksum:1655399370"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             int_value: 0
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         create_time_since_epoch: 1655401915607
#         last_update_time_since_epoch: 1655401919753
#         , artifact_type: id: 14
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         base_type: DATASET
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))
